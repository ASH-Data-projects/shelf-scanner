# %% [markdown]
# # Scanner usage example

# %%
from pathlib import Path
from ultralytics import YOLO
from app.scanner_api.app_models import Scanner, OrderModel # necessary imports.
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Model loading
#
# The `Scanner` model is a pipeline composed by two models: `YOLO` and `OrderModel`, so to use it, we have to load our `YOLO` and `OrderModel` models, then we give those models to our `Scanner` object when creating an instance.
#
# The `YOLO` model is loaded by giving the path to a yolo model file to the `YOLO` constructor, the `OrderModel` is loaded by giving it the path to .csv file that contains the data of a base shelf in the yolo format (columns being class, x, y, w, h).
#
# And that's it, we are ready to use it!

# %%
model_path = Path.cwd().parent/'models'/'my_model.pt'
shelf_path = Path.cwd().parent/'src'/'app'/'scanner_api'/'shelves'/'BATERIAS (1F) 0,36M.csv'
test_img = Path.cwd().parent/'data'/'test'/'test_img.jpg'

yolo_model = YOLO(model_path)
order_model = OrderModel(shelf_path)

scanner = Scanner(yolo_model=yolo_model, order_model=order_model)
pred = scanner.predict(test_img)
# Out:
# image 1/1 c:\Users\shade\OneDrive\Documentos\My coding projects\4geeks projects\shelf-scanner\data\test\test_img.jpg: 640x320 2 Bateria Duracell AA 2Unds, 1 Bateria Duracell AAA 2Und, 1 Bateria Energizer A23 2Und, 1 Bateria Energizer Max 9V, 2 Bateria Energizer Max AA 4 Unds, 2 Bateria Energizer Max AAA 2 Unds, 3 Bateria Energizer Max AAA 4 Unds, 1 Bateria Energizer Max C 2 Und, 1 Bateria Energizer Max D Alkalina 2 Und, 1 Bateria Kodak 9V EHD, 2 Bateria Philips Boton Litio 2032 X5s, 3 Bateria Philips Power Alkaline AA 2Unds, 3 Bateria Philips Power Alkaline AAA 2Unds, 2 Linterna Rayovac Recargable Mini 5 Leds, 292.7ms
# Speed: 7.5ms preprocess, 292.7ms inference, 16.4ms postprocess per image at shape (1, 3, 640, 320)

# %% [markdown]
# ## The ScannerResult class
#
# The `predict` method of the scanner object returns a `ScannerResult` object. This object is a dataclass that stores the results of the `YOLO` and `OrderModel` models. These results can be accessed using the `yolo_result` and `order_result` properties.

# %% [markdown]
# ### order_result
#
# The order result property stores a tuple containing two DataFrames.

# %%
print(f'order_result type: {type(pred.order_result)}')
print(f'order_result length: {len(pred.order_result)}')
# Out:
# order_result type: <class 'tuple'>
# order_result length: 2

# %% [markdown]
# The first DataFrame in the tuple contains the expected SKUs in the image that is being scanned. If the `expected_SKU` was found in the image in the position its given position (`pos` column), the `detected` value will be `True` for that product, if the product in the position was different from the `expected_SKU` it will be `False`.

# %%
pred.order_result[0]
# Out:
#     pos  cls                             expected_SKU  detected
# 0     0    4            Bateria Energizer Max AA 2Und     False
# 1     1   11      Bateria Philips Boton Litio 2032 X5      True
# 2     2   11      Bateria Philips Boton Litio 2032 X5      True
# 3     3   14   Linterna Rayovac Recargable Mini 5 Led      True
# 4     4   10                     Bateria Kodak 9V EHD      True
# 5     5    6          Bateria Energizer Max AAA 2 Und      True
# 6     6    8            Bateria Energizer Max C 2 Und      True
# 7     7    5           Bateria Energizer Max AA 4 Und      True
# 8     8    7          Bateria Energizer Max AAA 4 Und      True
# 9     9    9   Bateria Energizer Max D Alkalina 2 Und      True
# 10   10    4            Bateria Energizer Max AA 2Und     False
# 11   11    6          Bateria Energizer Max AAA 2 Und     False
# 12   12    2               Bateria Energizer A23 2Und      True
# 13   13    3                 Bateria Energizer Max 9V      True
# 14   14    7          Bateria Energizer Max AAA 4 Und      True
# 15   15   12   Bateria Philips Power Alkaline AA 2Und      True
# 16   16   12   Bateria Philips Power Alkaline AA 2Und      True
# 17   17   12   Bateria Philips Power Alkaline AA 2Und      True
# 18   18   13  Bateria Philips Power Alkaline AAA 2Und      True
# 19   19   13  Bateria Philips Power Alkaline AAA 2Und      True
# 20   20   13  Bateria Philips Power Alkaline AAA 2Und      True
# 21   21    0                 Bateria Duracell AA 2Und     False
# 22   22    0                 Bateria Duracell AA 2Und      True
# 23   23    1                Bateria Duracell AAA 2Und     False

# %% [markdown]
# The second DataFrame has a similar structure information related to the scanned image, in this DataFrame the `pos` column is calculated by the `OrderModel` model using the x, y values and the `detected_SKU` column stores SKU of the equivalent class detected by the `YOLO` model.

# %%
pred.order_result[1]
# Out:
#               x            y           w           h   cls  pos  \
# 0    515.326660   920.793701  374.496033  325.537018   6.0    0
# 1    750.055237   970.152710  572.886047  308.994873  11.0    1
# 2   1002.527771   980.635620  571.101746  255.014771  11.0    2
# 3   1288.149658  1056.921997  763.520203  350.074829  14.0    3
# 4    927.499390  1542.788330  367.885254  294.202087  10.0    4
# 5    551.247803  1474.695557  352.908813  322.426575   6.0    5
# 6   1284.710938  1971.519287  284.167603  259.483765   8.0    6
# 7    920.772705  1964.072754  292.219604  290.230225   5.0    7
# 8    593.534973  1970.721924  304.540039  291.999542   7.0    8
# 9   1291.052490  2332.344482  300.924805  270.568237  14.0    9
# 10  1290.641113  2333.573730  299.860107  273.001343   9.0    9
# 11   952.446594  2344.076660  297.216553  278.979126   5.0   10
# 12   607.527039  2362.198486  293.827637  285.182861   7.0   11
# 13  1301.739502  2696.895996  183.564697  141.292847   2.0   12
# 14   955.051147  2730.636719  287.756104  273.121094   3.0   13
# 15   633.786499  2727.127441  267.479248  276.151611   7.0   14
# 16   955.842590  3141.123779  289.954102  225.385620  12.0   15
# 17  1280.743896  3159.979004  285.673584  241.954956  12.0   16
# 18   650.037109  3148.477539  278.941895  231.558655  12.0   17
# 19   680.008301  3531.430176  306.950928  240.237000  13.0   18
# 20  1277.200684  3532.783691  294.024414  243.439087  13.0   19
# 21   977.611877  3491.279785  271.615967  233.164917  13.0   20
# 22   982.160400  3838.542480  284.513184  247.163513   1.0   21
# 23  1294.537109  3814.136963  287.955078  262.099487   0.0   22
# 24   694.055115  3845.270508  292.625732  258.112671   0.0   23
#
#                                detected_SKU
# 0           Bateria Energizer Max AAA 2 Und
# 1       Bateria Philips Boton Litio 2032 X5
# 2       Bateria Philips Boton Litio 2032 X5
# 3    Linterna Rayovac Recargable Mini 5 Led
# 4                      Bateria Kodak 9V EHD
# 5           Bateria Energizer Max AAA 2 Und
# 6             Bateria Energizer Max C 2 Und
# 7            Bateria Energizer Max AA 4 Und
# 8           Bateria Energizer Max AAA 4 Und
# 9    Linterna Rayovac Recargable Mini 5 Led
# 10   Bateria Energizer Max D Alkalina 2 Und
# 11           Bateria Energizer Max AA 4 Und
# 12          Bateria Energizer Max AAA 4 Und
# 13               Bateria Energizer A23 2Und
# 14                 Bateria Energizer Max 9V
# 15          Bateria Energizer Max AAA 4 Und
# 16   Bateria Philips Power Alkaline AA 2Und
# 17   Bateria Philips Power Alkaline AA 2Und
# 18   Bateria Philips Power Alkaline AA 2Und
# 19  Bateria Philips Power Alkaline AAA 2Und
# 20  Bateria Philips Power Alkaline AAA 2Und
# 21  Bateria Philips Power Alkaline AAA 2Und
# 22                Bateria Duracell AAA 2Und
# 23                 Bateria Duracell AA 2Und
# 24                 Bateria Duracell AA 2Und

# %%
pred.yolo_result
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'Bateria Duracell AA 2Und', 1: 'Bateria Duracell AAA 2Und', 2: 'Bateria Energizer A23 2Und', 3: 'Bateria Energizer Max 9V', 4: 'Bateria Energizer Max AA 2Und', 5: 'Bateria Energizer Max AA 4 Und', 6: 'Bateria Energizer Max AAA 2 Und', 7: 'Bateria Energizer Max AAA 4 Und', 8: 'Bateria Energizer Max C 2 Und', 9: 'Bateria Energizer Max D Alkalina 2 Und', 10: 'Bateria Kodak 9V EHD', 11: 'Bateria Philips Boton Litio 2032 X5', 12: 'Bateria Philips Power Alkaline AA 2Und', 13: 'Bateria Philips Power Alkaline AAA 2Und', 14: 'Linterna Rayovac Recargable Mini 5 Led'}
# obb: None
# orig_img: array([[[151, 161, 168],
#         [163, 173, 180],
#         [174, 184, 191],
#         ...,
#         [ 77, 144, 139],
#         [ 84, 151, 146],
#         [ 86, 153, 148]],
#
#        [[154, 164, 171],
#         [155, 165, 172],
#         [169, 179, 186],
#         ...,
#         [ 74, 141, 136],
#         [ 82, 149, 144],
#         [ 80, 147, 142]],
#
#        [[161, 171, 178],
#         [164, 174, 181],
#         [172, 182, 189],
#         ...,
#         [ 81, 148, 143],
#         [ 85, 152, 147],
#         [ 86, 153, 148]],
#
#        ...,
#
#        [[150, 168, 175],
#         [151, 169, 176],
#         [151, 169, 176],
#         ...,
#         [154, 179, 195],
#         [155, 180, 196],
#         [142, 167, 183]],
#
#        [[149, 167, 174],
#         [148, 166, 173],
#         [148, 166, 173],
#         ...,
#         [149, 174, 190],
#         [159, 184, 200],
#         [148, 173, 189]],
#
#        [[149, 167, 174],
#         [148, 166, 173],
#         [148, 166, 173],
#         ...,
#         [146, 171, 187],
#         [159, 184, 200],
#         [139, 164, 180]]], shape=(4080, 1884, 3), dtype=uint8)
# orig_shape: (4080, 1884)
# path: 'c:\\Users\\shade\\OneDrive\\Documentos\\My coding projects\\4geeks projects\\shelf-scanner\\data\\test\\test_img.jpg'
# probs: None
# save_dir: 'C:\\Users\\shade\\OneDrive\\Documentos\\My coding projects\\4geeks projects\\shelf-scanner\\src\\runs\\detect\\predict'
# speed: {'preprocess': 7.4666000000434, 'inference': 292.65780000423547, 'postprocess': 16.351899997971486}

# %% [markdown]
# ## example: printing the detection image

# %%
img_arr = pred.yolo_result.plot()
img = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis('off')
plt.show()
